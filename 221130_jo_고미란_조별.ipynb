# %%
import pandas as pd

# %%
## 데이터로드 와 살펴보기

# %% [markdown]
# ## 1. 데이터로드 와 살펴보기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#주피터사용시

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/미니플젝/seoul_inga.csv",encoding='utf-8') 


#메모장 다른이름으로 저장 바꿔줌 'cp949''euc-kr')
df
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (36,41,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         개방자치단체코드                    관리번호     인허가일자  인허가취소일자  영업상태코드  영업상태명  \
# 0        3130000  3130000-104-2022-00101  20220422      NaN       1  영업/정상
# 1        3230000  3230000-104-2022-00095  20220422      NaN       1  영업/정상
# 2        3230000  3230000-104-2022-00096  20220422      NaN       1  영업/정상
# 3        3180000  3180000-104-2022-00128  20220628      NaN       1  영업/정상
# 4        3120000  3120000-104-2022-00060  20220422      NaN       1  영업/정상
# ...          ...                     ...       ...      ...     ...    ...
# 120864   3130000  3130000-104-2014-00165  20140714      NaN       1  영업/정상
# 120865   3050000  3050000-104-2011-00066  20110726      NaN       3     폐업
# ...

# %%
df.columns
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '인허가취소일자', '영업상태코드', '영업상태명', '상세영업상태코드',
#        '상세영업상태명', '폐업일자', '휴업시작일자', '휴업종료일자', '재개업일자', '전화번호', '소재지면적',
#        '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명', '최종수정일자', '데이터갱신구분',
#        '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '위생업태명', '남성종사자수', '여성종사자수',
#        '영업장주변구분명', '등급구분명', '급수시설구분명', '총인원', '본사종업원수', '공장사무직종업원수',
#        '공장판매직종업원수', '공장생산직종업원수', '건물소유구분명', '보증액', '월세액', '다중이용업소여부', '시설총규모',
#        '전통업소지정번호', '전통업소주된음식', '홈페이지'],
#       dtype='object')

# %%
df.shape
# Out:
# (120869, 44)

# %%
### 칼럼전처리

# %% [markdown]
# ## 2. 칼럼 등 전처리하기

# %%
df=df.drop(['인허가취소일자','휴업시작일자','휴업종료일자', '재개업일자',
         '건물소유구분명','전통업소주된음식','전통업소지정번호','홈페이지'],axis=1) 
df.head()
# Out:
#    개방자치단체코드                    관리번호     인허가일자  영업상태코드  영업상태명  상세영업상태코드  \
# 0   3130000  3130000-104-2022-00101  20220422       1  영업/정상         1
# 1   3230000  3230000-104-2022-00095  20220422       1  영업/정상         1
# 2   3230000  3230000-104-2022-00096  20220422       1  영업/정상         1
# 3   3180000  3180000-104-2022-00128  20220628       1  영업/정상         1
# 4   3120000  3120000-104-2022-00060  20220422       1  영업/정상         1
#
#   상세영업상태명  폐업일자 전화번호   소재지면적  ...  급수시설구분명 총인원 본사종업원수  공장사무직종업원수 공장판매직종업원수  \
# 0      영업   NaN  NaN   89.25  ...      NaN NaN    NaN        NaN       NaN
# 1      영업   NaN  NaN   22.96  ...      NaN NaN    NaN        NaN       NaN
# 2      영업   NaN  NaN    3.30  ...      NaN NaN    NaN        NaN       NaN
# 3      영업   NaN  NaN   11.34  ...      NaN NaN    NaN        NaN       NaN
# 4      영업   NaN  NaN  231.01  ...      NaN NaN    NaN        NaN       NaN
#
#    공장생산직종업원수 보증액 월세액 다중이용업소여부  시설총규모
# 0        NaN NaN NaN      NaN    NaN
# ...

# %%
len(df.columns)
# Out:
# 36

# %%
#df=
df=df[df['업태구분명']=='커피숍']#.shape

# %%
df['개방자치단체코드'].value_counts()
# Out:
# 3220000    3447
# 3210000    2405
# 3130000    2286
# 3150000    1829
# 3010000    1819
# 3180000    1615
# 3000000    1503
# 3230000    1446
# 3240000    1256
# 3200000    1229
# 3120000    1171
# 3040000    1105
# 3140000    1051
# 3100000    1004
# 3070000     999
# 3190000     964
# 3160000     957
# 3020000     948
# 3030000     921
# 3050000     874
# 3110000     824
# 3170000     752
# 3060000     736
# 3090000     551
# 3080000     488
# Name: 개방자치단체코드, dtype: int64

# %%
df=df[df['개방자치단체코드']== 3180000]
#df3[df3['개방자치단체코드']==3180000]

# %%
df.shape
# Out:
# (1615, 36)

# %%
df.head()
# Out:
#       개방자치단체코드                    관리번호     인허가일자  영업상태코드  영업상태명  상세영업상태코드  \
# 3      3180000  3180000-104-2022-00128  20220628       1  영업/정상         1
# 1232   3180000  3180000-104-2022-00084  20220419       1  영업/정상         1
# 1322   3180000  3180000-104-2022-00076  20220414       1  영업/정상         1
# 1334   3180000  3180000-104-2022-00074  20220413       1  영업/정상         1
# 1446   3180000  3180000-104-2011-00166  20111202       3     폐업         2
#
#      상세영업상태명        폐업일자          전화번호  소재지면적  ...  급수시설구분명 총인원 본사종업원수  \
# 3         영업         NaN           NaN  11.34  ...      NaN NaN    NaN
# 1232      영업         NaN           NaN  74.00  ...      NaN NaN    NaN
# 1322      영업         NaN           NaN  27.56  ...      NaN NaN    NaN
# 1334      영업         NaN           NaN   5.00  ...      NaN NaN    NaN
# 1446      폐업  20121025.0  02  783 2888  50.00  ...    상수도전용 NaN    NaN
#
#       공장사무직종업원수 공장판매직종업원수  공장생산직종업원수 보증액 월세액 다중이용업소여부  시설총규모
# ...

# %%
df.isna().sum()
# Out:
# 개방자치단체코드        0
# 관리번호            0
# 인허가일자           0
# 영업상태코드          0
# 영업상태명           0
# 상세영업상태코드        0
# 상세영업상태명         0
# 폐업일자          817
# 전화번호         1176
# 소재지면적          28
# 소재지우편번호         1
# 지번주소            1
# 도로명주소         101
# 도로명우편번호       118
# 사업장명            0
# 최종수정일자          0
# 데이터갱신구분         0
# 데이터갱신일자         0
# 업태구분명           0
# 좌표정보(X)         9
# 좌표정보(Y)         9
# 위생업태명         185
# 남성종사자수       1428
# 여성종사자수       1428
# 영업장주변구분명     1601
# 등급구분명        1609
# 급수시설구분명      1410
# 총인원          1480
# 본사종업원수       1480
# 공장사무직종업원수    1480
# 공장판매직종업원수    1480
# 공장생산직종업원수    1480
# 보증액          1480
# 월세액          1480
# 다중이용업소여부      185
# 시설총규모         185
# dtype: int64

# %%
df['영업상태코드'].value_counts()
# Out:
# 1    817
# 3    798
# Name: 영업상태코드, dtype: int64

# %%
df['상세영업상태코드'].value_counts()
# Out:
# 1    817
# 2    798
# Name: 상세영업상태코드, dtype: int64

# %%
df['상세영업상태명'].value_counts()
# Out:
# 영업    817
# 폐업    798
# Name: 상세영업상태명, dtype: int64

# %%
df.columns
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '영업상태코드', '영업상태명', '상세영업상태코드', '상세영업상태명',
#        '폐업일자', '전화번호', '소재지면적', '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명',
#        '최종수정일자', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '위생업태명',
#        '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총인원', '본사종업원수',
#        '공장사무직종업원수', '공장판매직종업원수', '공장생산직종업원수', '보증액', '월세액', '다중이용업소여부',
#        '시설총규모'],
#       dtype='object')

# %%
# #관리번호-여기 오류나서 지움여-이거 할 필요없는거임 위에서 이미 함-오류해결

# df=df.drop(['휴업시작일자','휴업종료일자', '재개업일자','건물소유구분명','전통업소주된음식','전통업소지정번호','홈페이지'],axis=1)

# %%
df['폐업일자'].value_counts()
# Out:
# 20190214.0    16
# 20220720.0     3
# 20091216.0     3
# 20201230.0     3
# 20220719.0     3
#               ..
# 20130326.0     1
# 20181109.0     1
# 20130405.0     1
# 20180409.0     1
# 20160331.0     1
# Name: 폐업일자, Length: 686, dtype: int64

# %%
#여기까지
# Index(['개방자치단체코드', '상세영업상태코드',  '소재지면적', '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명',
#        '최종수정일자', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '위생업태명',
#        '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총인원', '본사종업원수',
#        '공장사무직종업원수', '공장판매직종업원수', '공장생산직종업원수', '보증액', '월세액', '다중이용업소여부',
#        '시설총규모'],

# %%
# df=df.drop(['관리번호', '인허가일자', '영업상태코드', '영업상태명', '상세영업상태명', '폐업일자', '전화번호'],axis=1) 
# df.shape

# %%
#df['공장사무직종업원수'].isna()

# %%
#df[df['소재지면적'].isna()]['여성종사자수'] #면적값->최빈값 ->#면적값에 의미가 있긴 함. -> 하지만 여성종사자수로는 면적의 널값을 채울 수 없다

# %%
df.columns
# Out:
# Index(['개방자치단체코드', '관리번호', '인허가일자', '영업상태코드', '영업상태명', '상세영업상태코드', '상세영업상태명',
#        '폐업일자', '전화번호', '소재지면적', '소재지우편번호', '지번주소', '도로명주소', '도로명우편번호', '사업장명',
#        '최종수정일자', '데이터갱신구분', '데이터갱신일자', '업태구분명', '좌표정보(X)', '좌표정보(Y)', '위생업태명',
#        '남성종사자수', '여성종사자수', '영업장주변구분명', '등급구분명', '급수시설구분명', '총인원', '본사종업원수',
#        '공장사무직종업원수', '공장판매직종업원수', '공장생산직종업원수', '보증액', '월세액', '다중이용업소여부',
#        '시설총규모'],
#       dtype='object')

# %%
df=df[['상세영업상태코드', '소재지면적', '지번주소', '사업장명', '업태구분명', '좌표정보(X)', '좌표정보(Y)']]
#['상세영업상태코드', '소재지면적', '지번주소', '사업장명', '업태구분명', '좌표정보(X)', '좌표정보(Y)']
df.head()
# Out:
#       상세영업상태코드  소재지면적                                              지번주소  \
# 3            1  11.34                             서울특별시 영등포구 문래동3가 82-3
# 1232         1  74.00                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌
# 1322         1  27.56                           서울특별시 영등포구 여의도동 37 아일렉스
# 1334         1   5.00                              서울특별시 영등포구 문래동4가 7-1
# 1446         2  50.00  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)
#
#                    사업장명 업태구분명        좌표정보(X)        좌표정보(Y)
# 3                그리고 커피   커피숍  190310.553875  446496.894116
# 1232  더블플랫(DOUBLE FLAT)   커피숍  190757.977577  448162.410634
# 1322     매머드익스프레스 여의도역점   커피숍  193209.283508  446474.956573
# 1334              라라라핸즈   커피숍  190263.634968  445995.050159
# 1446               카페믹스   커피숍  192747.419300  447054.988337

# %%
#df.drop(['관리번호', '인허가일자', '영업상태코드', '영업상태명', '상세영업상태명', '폐업일자', '전화번호'],axis=1) 
#df.shape

# %%
lst_na3 = ['소재지우편번호', '도로명우편번호', '최종수정일자', '데이터갱신구분', '데이터갱신일자', '위생업태명',
   '남성종사자수', '여성종사자수', '영업장주변구분명',  '등급구분명', '급수시설구분명', '총인원',  '본사종업원수',
   '공장사무직종업원수', '공장판매직종업원수', '공장생산직종업원수', '보증액', '월세액', '다중이용업소여부', '시설총규모']

# %%
#df=df.drop(lst_na3,axis=1) 
#df.shape

# %%
df.columns
# Out:
# Index(['상세영업상태코드', '소재지면적', '지번주소', '사업장명', '업태구분명', '좌표정보(X)', '좌표정보(Y)'], dtype='object')

# %%
df.value_counts()
# Out:
# 상세영업상태코드  소재지면적   지번주소                                          사업장명             업태구분명  좌표정보(X)        좌표정보(Y)
# 2         3.30    서울특별시 영등포구 영등포동4가 434-5번지 신세계백화점 지하1층         코코진              커피숍    191581.500266  446108.807193    2
# 1         51.50   서울특별시 영등포구 영등포동3가 9-51                        공차 영등포역점         커피숍    191658.806565  446124.140283    2
# 2         35.30   서울특별시 영등포구 여의도동 14-21번지 LG에클라트 지상1층112호(일부)   타임테이블            커피숍    192785.997964  447523.116512    2
#           26.45   서울특별시 영등포구 양평동1가 9-1                          에스프레소는진짜다        커피숍    190313.138089  446632.690937    1
#           27.07   서울특별시 영등포구 영등포동 618-496번지 롯데백화점 지하1층          카페제이브라운          커피숍    191741.345848  445970.307641    1
#                                                                                                                        ..
# 1         57.27   서울특별시 영등포구 양평동3가 46 이앤씨드림타워                   커피사피엔스 이앤씨드림타워점  커피숍    190364.652011  447158.946262    1
# ...

# %%
df.columns
# Out:
# Index(['상세영업상태코드', '소재지면적', '지번주소', '사업장명', '업태구분명', '좌표정보(X)', '좌표정보(Y)'], dtype='object')

# %%
#df=df.drop('개방자치단체코드',axis=1)

# %%
df.isna().sum()
# Out:
# 상세영업상태코드     0
# 소재지면적       28
# 지번주소         1
# 사업장명         0
# 업태구분명        0
# 좌표정보(X)      9
# 좌표정보(Y)      9
# dtype: int64

# %%
df.head()
# Out:
#       상세영업상태코드  소재지면적                                              지번주소  \
# 3            1  11.34                             서울특별시 영등포구 문래동3가 82-3
# 1232         1  74.00                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌
# 1322         1  27.56                           서울특별시 영등포구 여의도동 37 아일렉스
# 1334         1   5.00                              서울특별시 영등포구 문래동4가 7-1
# 1446         2  50.00  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)
#
#                    사업장명 업태구분명        좌표정보(X)        좌표정보(Y)
# 3                그리고 커피   커피숍  190310.553875  446496.894116
# 1232  더블플랫(DOUBLE FLAT)   커피숍  190757.977577  448162.410634
# 1322     매머드익스프레스 여의도역점   커피숍  193209.283508  446474.956573
# 1334              라라라핸즈   커피숍  190263.634968  445995.050159
# 1446               카페믹스   커피숍  192747.419300  447054.988337

# %%
df[df['지번주소'].isna()]
# Out:
#        상세영업상태코드  소재지면적 지번주소                             사업장명 업태구분명  \
# 76609         1   22.0  NaN  킹콩쥬스&커피(KINGKONG JUICE &COFFEE)   커피숍
#
#              좌표정보(X)        좌표정보(Y)
# 76609  190685.058136  446978.984203

# %%
#서울특별시 영등포구 당산동3가 364

# %%
df.loc[df['지번주소'].isna(),'지번주소'] = '서울특별시 영등포구 당산동3가 364'

# %%
df.loc[76609]
# Out:
# 상세영업상태코드                                  1
# 소재지면적                                  22.0
# 지번주소                   서울특별시 영등포구 당산동3가 364
# 사업장명        킹콩쥬스&커피(KINGKONG JUICE &COFFEE)
# 업태구분명                                   커피숍
# 좌표정보(X)                       190685.058136
# 좌표정보(Y)                       446978.984203
# Name: 76609, dtype: object

# %%
#df=df.drop(['도로명주소'],axis=1)

# %%
df_origin=df.copy() #나중에 시각화 때문에 
df_origin.head()
# Out:
#       상세영업상태코드  소재지면적                                              지번주소  \
# 3            1  11.34                             서울특별시 영등포구 문래동3가 82-3
# 1232         1  74.00                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌
# 1322         1  27.56                           서울특별시 영등포구 여의도동 37 아일렉스
# 1334         1   5.00                              서울특별시 영등포구 문래동4가 7-1
# 1446         2  50.00  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)
#
#                    사업장명 업태구분명        좌표정보(X)        좌표정보(Y)
# 3                그리고 커피   커피숍  190310.553875  446496.894116
# 1232  더블플랫(DOUBLE FLAT)   커피숍  190757.977577  448162.410634
# 1322     매머드익스프레스 여의도역점   커피숍  193209.283508  446474.956573
# 1334              라라라핸즈   커피숍  190263.634968  445995.050159
# 1446               카페믹스   커피숍  192747.419300  447054.988337

# %%
df.head()
# Out:
#       상세영업상태코드  소재지면적                                              지번주소  \
# 3            1  11.34                             서울특별시 영등포구 문래동3가 82-3
# 1232         1  74.00                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌
# 1322         1  27.56                           서울특별시 영등포구 여의도동 37 아일렉스
# 1334         1   5.00                              서울특별시 영등포구 문래동4가 7-1
# 1446         2  50.00  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)
#
#                    사업장명 업태구분명        좌표정보(X)        좌표정보(Y)
# 3                그리고 커피   커피숍  190310.553875  446496.894116
# 1232  더블플랫(DOUBLE FLAT)   커피숍  190757.977577  448162.410634
# 1322     매머드익스프레스 여의도역점   커피숍  193209.283508  446474.956573
# 1334              라라라핸즈   커피숍  190263.634968  445995.050159
# 1446               카페믹스   커피숍  192747.419300  447054.988337

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1615 entries, 3 to 120835
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상세영업상태코드  1615 non-null   int64
#  1   소재지면적     1587 non-null   float64
#  2   지번주소      1615 non-null   object
#  3   사업장명      1615 non-null   object
#  4   업태구분명     1615 non-null   object
#  5   좌표정보(X)   1606 non-null   float64
#  6   좌표정보(Y)   1606 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 165.5+ KB

# %%
df['지번주소'].str.split(' ')
# Out:
# 3                                [서울특별시, 영등포구, 문래동3가, 82-3]
# 1232                     [서울특별시, 영등포구, 양평동4가, 51-1, 경남아너스빌]
# 1322                          [서울특별시, 영등포구, 여의도동, 37, 아일렉스]
# 1334                              [서울특별시, 영등포구, 문래동4가, 7-1]
# 1446      [서울특별시, 영등포구, 여의도동, 17번지, 더?아일랜드파크, 지상1층, 102-...
#                                 ...
# 120786                           [서울특별시, 영등포구, 문래동2가, 17-1]
# 120788                            [서울특별시, 영등포구, 당산동1가, 238]
# 120790                          [서울특별시, 영등포구, 문래동3가, 77-45]
# 120791                     [서울특별시, 영등포구, 문래동5가, 9, 벽산디지털밸리]
# 120835                  [서울특별시, 영등포구, 대림동, 651-5, 한국상하수도협회]
# Name: 지번주소, Length: 1615, dtype: object

# %%
a=df['지번주소'].str.split(' ',expand=True)#.str.split('동')#[2]
a
# Out:
#            0     1      2      3         4     5             6     7     8   \
# 3       서울특별시  영등포구  문래동3가   82-3      None  None          None  None  None
# 1232    서울특별시  영등포구  양평동4가   51-1    경남아너스빌  None          None  None  None
# 1322    서울특별시  영등포구   여의도동     37      아일렉스  None          None  None  None
# 1334    서울특별시  영등포구  문래동4가    7-1      None  None          None  None  None
# 1446    서울특별시  영등포구   여의도동   17번지  더?아일랜드파크  지상1층  102-106호(전체)        None
# ...       ...   ...    ...    ...       ...   ...           ...   ...   ...
# 120786  서울특별시  영등포구  문래동2가   17-1      None  None          None  None  None
# 120788  서울특별시  영등포구  당산동1가    238      None  None          None  None  None
# 120790  서울특별시  영등포구  문래동3가  77-45      None  None          None  None  None
# 120791  서울특별시  영등포구  문래동5가      9   벽산디지털밸리  None          None  None  None
# 120835  서울특별시  영등포구    대림동  651-5  한국상하수도협회  None          None  None  None
#
#           9     10    11
# 3       None  None  None
# ...

# %%
b=a[2].str.split('동',expand=True)
b
# Out:
#           0   1
# 3        문래  3가
# 1232     양평  4가
# 1322    여의도
# 1334     문래  4가
# 1446    여의도
# ...     ...  ..
# 120786   문래  2가
# 120788   당산  1가
# 120790   문래  3가
# 120791   문래  5가
# 120835   대림
#
# [1615 rows x 2 columns]

# %%
d=b[[0]].apply(lambda x : x+'동')
d
# Out:
#            0
# 3        문래동
# 1232     양평동
# 1322    여의도동
# 1334     문래동
# 1446    여의도동
# ...      ...
# 120786   문래동
# 120788   당산동
# 120790   문래동
# 120791   문래동
# 120835   대림동
#
# [1615 rows x 1 columns]

# %%
df['지번주소']=d
df.head()
# Out:
#       상세영업상태코드  소재지면적  지번주소               사업장명 업태구분명        좌표정보(X)  \
# 3            1  11.34   문래동             그리고 커피   커피숍  190310.553875
# 1232         1  74.00   양평동  더블플랫(DOUBLE FLAT)   커피숍  190757.977577
# 1322         1  27.56  여의도동     매머드익스프레스 여의도역점   커피숍  193209.283508
# 1334         1   5.00   문래동              라라라핸즈   커피숍  190263.634968
# 1446         2  50.00  여의도동               카페믹스   커피숍  192747.419300
#
#             좌표정보(Y)
# 3     446496.894116
# 1232  448162.410634
# 1322  446474.956573
# 1334  445995.050159
# 1446  447054.988337

# %%
#동호님 코드
# a = df['지번주소'].str.split(' ',n=3,expand=True)
# a[2]
# d = a[2].apply(lambda x: x.split('동')[0]+'동')
# d 
# df['지번주소']=d

df['지번주소'].apply(lambda x: x.split('동')[0]+'동')
# Out:
# 3          문래동
# 1232       양평동
# 1322      여의도동
# 1334       문래동
# 1446      여의도동
#           ...
# 120786     문래동
# 120788     당산동
# 120790     문래동
# 120791     문래동
# 120835     대림동
# Name: 지번주소, Length: 1615, dtype: object

# %%
df['지번주소'].value_counts()
# Out:
# 여의도동    478
# 영등포동    286
# 당산동     240
# 신길동     174
# 문래동     155
# 양평동     152
# 대림동      94
# 도림동      34
# 양화동       2
# Name: 지번주소, dtype: int64

# %%
df['지번주소'].isna().sum()
# Out:
# 0

# %%
#a[2].str.endswith('동')  #얘는 불린 형태로 보인다. pass

# %%
df.isna().sum() #이거 좌표 채우기는 나중에 하자.  #폴리움 이떄 다 

#시각화 시에 주소는 보이지 않는다.
#
# Out:
# 상세영업상태코드     0
# 소재지면적       28
# 지번주소         0
# 사업장명         0
# 업태구분명        0
# 좌표정보(X)      9
# 좌표정보(Y)      9
# dtype: int64

# %%
dong=pd.read_excel('/content/drive/MyDrive/Colab Notebooks/미니플젝/동별 상권분석.xlsx')
dong
# Out:
#        동 동 자세히  매출(만원)   업소갯수
# 0    신길동    1동  1727.0   12.0
# 1    신길동    2동  1497.0   35.0
# 2    신길동    3동   399.0   17.0
# 3    신길동    4동   444.0   14.0
# 4    신길동    5동   846.0   11.0
# 5    신길동    6동  1446.0   27.0
# 6    신길동    7동  1546.0   10.0
# 7    당산동    1동  1264.0   79.0
# 8    당산동    2동  1947.0   66.0
# 9   영등포동  영등포동  1440.0  114.0
# 10  여의도동  여의도동  2197.0  238.0
# 11   문래동   문래동  1805.0   93.0
# 12   양평동    1동   870.0   51.0
# 13   양평동    2동   801.0   72.0
# 14   대림동    1동  1643.0   16.0
# 15   대림동    2동  2063.0    9.0
# 16   대림동    3동  1504.0   35.0
# 17   도림동   도림동  1755.0   20.0

# %%
dong.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   동       18 non-null     object
#  1   동 자세히   18 non-null     object
#  2   매출(만원)  18 non-null     float64
#  3   업소갯수    18 non-null     float64
# dtypes: float64(2), object(2)
# memory usage: 704.0+ bytes

# %%
#dong['매출(만원)'].astype(int)  #이따가 통일시켜주자.

# %%
#dong['매출(만원)'].str.replace('1','')

# %%
df.shape
# Out:
# (1615, 7)

# %%
dong['업소갯수'].sum() #업소갯수에 차이는 있다.->논의필요
# Out:
# 919.0

# %%
#221130 중간에 살린 데이터프레임들만 나머지는 #처리하기
#틀린코드->수정필요!
#dong.groupby('동').sum()

# %%
df['지번주소'].value_counts().to_frame() #이게 맞는코드 
#근데 이 갯수가 더 많다. df를 따라가자.
#왜곡 하는 이유를 시나리오를 잘 짜야 한다.
# Out:
#       지번주소
# 여의도동   478
# 영등포동   286
# 당산동    240
# 신길동    174
# 문래동    155
# 양평동    152
# 대림동     94
# 도림동     34
# 양화동      2

# %%
#양화 모든 정보를 제거
df[df['지번주소']=='양화동']
# Out:
#        상세영업상태코드   소재지면적 지번주소  사업장명 업태구분명      좌표정보(X)        좌표정보(Y)
# 76457         1   15.00  양화동  카페도하   커피숍          NaN            NaN
# 80478         2  275.56  양화동  까페나루   커피숍  191061.8202  449045.705457

# %%
df.drop([76457],inplace=True)
df.drop([80478],inplace=True)

# %%
df.shape
# Out:
# (1613, 7)

# %%
df.groupby('지번주소').sum()[['상세영업상태코드']]
# Out:
#       상세영업상태코드
# 지번주소
# 당산동        368
# 대림동        130
# 도림동         50
# 문래동        234
# 신길동        255
# 양평동        227
# 여의도동       713
# 영등포동       433

# %%
df.columns
# Out:
# Index(['상세영업상태코드', '소재지면적', '지번주소', '사업장명', '업태구분명', '좌표정보(X)', '좌표정보(Y)'], dtype='object')

# %%
df[df['소재지면적'].isna()]
# Out:
#        상세영업상태코드  소재지면적  지번주소                            사업장명 업태구분명  \
# 1488          2    NaN  영등포동                           동남커피숍   커피숍
# 2339          2    NaN  영등포동                            크레미뇽   커피숍
# 75591         1    NaN   신길동                           프렌치키스   커피숍
# 75607         1    NaN  여의도동                  스타벅스 롯데캐슬 여의도점   커피숍
# 75634         1    NaN  여의도동                         이디야라이프점   커피숍
# 75713         1    NaN  여의도동                커피빈코리아 여의도 34번지점   커피숍
# 77010         1    NaN   대림동                             일심당   커피숍
# 77260         1    NaN   대림동  컴포즈커피 영등포아델포레점(COMPOSE COFFEE)   커피숍
# 77940         2    NaN  여의도동                         이디야KBS점   커피숍
# 77956         2    NaN  여의도동                      나라플라워커피전문점   커피숍
# 78042         2    NaN  영등포동                갓볶은커피(보그너커피영등포점)   커피숍
# 78043         2    NaN  여의도동                            아르카페   커피숍
# 78054         2    NaN  영등포동                        이삭토스트체인점   커피숍
# ...

# %%
#면적의 크기는 제곱미터

# %%
df_origin.sample(10)#['소재지면적'].mean()
# Out:
#        상세영업상태코드   소재지면적                                       지번주소  \
# 78525         2   31.20      서울특별시 영등포구 문래동6가 8번지 문래임광그대가 1층 104호
# 75698         1   32.55  서울특별시 영등포구 대림동 1120번지 온누리아파트상가 1층 106-1호
# 77172         1  259.02       서울특별시 영등포구 양평동1가 247 영등포 중흥 S-CLASS
# 76346         1   24.97                  서울특별시 영등포구 여의도동 50 7동 15호
# 76629         1   76.68                     서울특별시 영등포구 문래동2가 13-2
# 80585         2   42.29             서울특별시 영등포구 당산동4가 1-146번지 1층일부
# 81297         2   51.39               서울특별시 영등포구 영등포동 618-69 지상1층
# 77384         1   42.90                    서울특별시 영등포구 여의도동 22 파크원
# 77145         1   36.30                    서울특별시 영등포구 양평동3가 78-19
# 79010         2   27.00      서울특별시 영등포구 양평동3가 102번지 우림루미아트상가 101호
#
#                      사업장명 업태구분명        좌표정보(X)        좌표정보(Y)
# 78525      위드파오(WITH PAO)   커피숍  190107.271464  446454.594612
# 75698                수제달달   커피숍  191484.515323  443691.031418
# ...

# %%
df_origin[df_origin['소재지면적'].isna()]
# Out:
#        상세영업상태코드  소재지면적                                            지번주소  \
# 1488          2    NaN                     서울특별시 영등포구 영등포동2가 34-140번지
# 2339          2    NaN                  서울특별시 영등포구 영등포동4가 434-5 신세계백화점
# 75591         1    NaN                          서울특별시 영등포구 신길동 18-3번지
# 75607         1    NaN           서울특별시 영등포구 여의도동 36 롯데캐슬 앰파이어 1층 104호
# 75634         1    NaN       서울특별시 영등포구 여의도동 61-3번지 라이프오피스텔 지하1층 44호동
# 75713         1    NaN  서울특별시 영등포구 여의도동 34-1 SIMPAC 빌딩 1층 (구MBC 경영센터)
# 77010         1    NaN                    서울특별시 영등포구 대림동 706-1 88월드타워
# 77260         1    NaN             서울특별시 영등포구 대림동 1127 e편한세상 영등포 아델포레
# 77940         2    NaN                  서울특별시 영등포구 여의도동 18번지 한국방송공사2층
# 77956         2    NaN            서울특별시 영등포구 여의도동 43-4번지 롯데아이비상가 105호
# 78042         2    NaN                        서울특별시 영등포구 영등포동2가 147번지
# 78043         2    NaN                      서울특별시 영등포구 여의도동 45-1번지 1층
# ...

# %%
#내가 맡은 널값
print(df_origin.loc[75634,['사업장명','지번주소']])
print(df_origin.loc[75713,['사업장명','지번주소']])
print(df_origin.loc[77010,['사업장명','지번주소']])
print(df_origin.loc[77260,['사업장명','지번주소']])
# df.origin([75713])
# df.origin([77010])
# df.origin([77260])
# Out:
# 사업장명                                      이디야라이프점
# 지번주소    서울특별시 영등포구 여의도동 61-3번지 라이프오피스텔 지하1층 44호동
# Name: 75634, dtype: object
# 사업장명                                  커피빈코리아 여의도 34번지점
# 지번주소    서울특별시 영등포구 여의도동 34-1 SIMPAC 빌딩 1층 (구MBC 경영센터)
# Name: 75713, dtype: object
# 사업장명                             일심당
# 지번주소    서울특별시 영등포구 대림동 706-1 88월드타워
# Name: 77010, dtype: object
# 사업장명         컴포즈커피 영등포아델포레점(COMPOSE COFFEE)
# 지번주소    서울특별시 영등포구 대림동 1127 e편한세상 영등포 아델포레
# Name: 77260, dtype: object

# %%
#면적의 널값소환
df.columns
# Out:
# Index(['상세영업상태코드', '소재지면적', '지번주소', '사업장명', '업태구분명', '좌표정보(X)', '좌표정보(Y)'], dtype='object')

# %%
#분담역할:난값을 채우는 코드 작성하기
#일단 수정 코드 작성->포문 넣을 수 있으면 포문 넣는걸로

#정보 뽑아내면

#df.loc[df['지번주소'].isna(),'지번주소'] = '서울특별시 영등포구 당산동3가 364'

#한 두개가 아니라 이렇게 하면 안돼
#df.loc[df['소재지면적'.isna(),'소재지면적']

nul=[1488,2339,75591,75607,75634,75713,77010,77260,77940,77956,78042,78043,78054,78103,78122,78139,78149,78160,78309,78347,78369,78499,78574,78576,78578,78652,78703,78799]
len(nul)
# Out:
# 28

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1613 entries, 3 to 120835
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   상세영업상태코드  1613 non-null   int64
#  1   소재지면적     1585 non-null   float64
#  2   지번주소      1613 non-null   object
#  3   사업장명      1613 non-null   object
#  4   업태구분명     1613 non-null   object
#  5   좌표정보(X)   1605 non-null   float64
#  6   좌표정보(Y)   1605 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 100.8+ KB

# %%
#하나만해보기 
#df.loc[1488,'소재지면적']=30

# %%
# #잠깐 연습-성공
# test=[1488,75634,75713,77010]
# myun=[30,89.15,97,49]
# test2=[]
# for t,m in zip(test,myun):
#   test2.append(t+m)
# print(test2)

# %%
#바꾸기 전 확인
df.loc[75634]
# Out:
# 상세영업상태코드                1
# 소재지면적                 NaN
# 지번주소                 여의도동
# 사업장명              이디야라이프점
# 업태구분명                 커피숍
# 좌표정보(X)     194561.746032
# 좌표정보(Y)     446364.318286
# Name: 75634, dtype: object

# %%
# #연습한번더-성공
# nul=[1488,2339,75591,75607,75634,75713,77010,77260,77940,77956,78042,78043,78054,78103,78122,78139,78149,78160,78309,78347,78369,78499,78574,78576,78578,78652,78703,78799]
# #len(nul)
# test=[1488,75634,75713,77010]
# myun=[30,89.15,97,49]
# for t,m in zip(test,myun):
#   #df.loc[1488,'소재지면적']=30
#   df.loc[t,'소재지면적']= m

# %%
#바꾼 후 확인
df.loc[1488]
# Out:
# 상세영업상태코드                2
# 소재지면적                 NaN
# 지번주소                 영등포동
# 사업장명                동남커피숍
# 업태구분명                 커피숍
# 좌표정보(X)     191843.332642
# 좌표정보(Y)     446443.299077
# Name: 1488, dtype: object

# %%
df['소재지면적'].mean()
# Out:
# 63.66303470031546

# %%
myun=[30,30,20,120,89.15,97,49,30,33,66,66,132,33,63.66,66,66,66,120,33,33,66,33,63.66,63.66,119.008,40,63.66,79.6]
len(myun)
# Out:
# 28

# %%
#최종->#소재지면적의 널값 처리하기 
nul=[1488,2339,75591,75607,75634,75713,77010,77260,77940,77956,78042,78043,78054,78103,78122,78139,78149,78160,78309,78347,78369,78499,78574,78576,78578,78652,78703,78799]

myun=[30,30,20,120,89.15,97,49,30,33,66,66,132,33,63.66,66,66,66,120,33,33,66,33,63.66,63.66,119.008,40,63.66,79.6]
for n,m in zip(nul,myun):
  #df.loc[1488,'소재지면적']=30
  df.loc[n,'소재지면적']= m

#확인
#df[df['소재지면적'].isna()] #아무것도안떠야 성공

# %%
df[df['소재지면적'].isna()]
# Out:
# Empty DataFrame
# Columns: [상세영업상태코드, 소재지면적, 지번주소, 사업장명, 업태구분명, 좌표정보(X), 좌표정보(Y)]
# Index: []

# %%
df.isna().sum()
# Out:
# 상세영업상태코드    0
# 소재지면적       0
# 지번주소        0
# 사업장명        0
# 업태구분명       0
# 좌표정보(X)     8
# 좌표정보(Y)     8
# dtype: int64

# %%
j=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/미니플젝/df_origin.csv",encoding='utf-8') 
j.head()
# Out:
#    Unnamed: 0  상세영업상태코드  소재지면적  \
# 0           3         1  11.34
# 1        1232         1  74.00
# 2        1322         1  27.56
# 3        1334         1   5.00
# 4        1446         2  50.00
#
#                                                지번주소               사업장명 업태구분명  \
# 0                             서울특별시 영등포구 문래동3가 82-3             그리고 커피   커피숍
# 1                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌  더블플랫(DOUBLE FLAT)   커피숍
# 2                           서울특별시 영등포구 여의도동 37 아일렉스     매머드익스프레스 여의도역점   커피숍
# 3                              서울특별시 영등포구 문래동4가 7-1              라라라핸즈   커피숍
# 4  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)                카페믹스   커피숍
#
#      좌표정보(X)     좌표정보(Y)
# 0  37.520618  126.891165
# 1  37.535550  126.896113
# 2  37.521024  126.924012
# 3  37.516095  126.890646
# 4  37.526039  126.918643

# %%
df_origin=j.copy()
df_origin.head()
# Out:
#    Unnamed: 0  상세영업상태코드  소재지면적  \
# 0           3         1  11.34
# 1        1232         1  74.00
# 2        1322         1  27.56
# 3        1334         1   5.00
# 4        1446         2  50.00
#
#                                                지번주소               사업장명 업태구분명  \
# 0                             서울특별시 영등포구 문래동3가 82-3             그리고 커피   커피숍
# 1                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌  더블플랫(DOUBLE FLAT)   커피숍
# 2                           서울특별시 영등포구 여의도동 37 아일렉스     매머드익스프레스 여의도역점   커피숍
# 3                              서울특별시 영등포구 문래동4가 7-1              라라라핸즈   커피숍
# 4  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)                카페믹스   커피숍
#
#      좌표정보(X)     좌표정보(Y)
# 0  37.520618  126.891165
# 1  37.535550  126.896113
# 2  37.521024  126.924012
# 3  37.516095  126.890646
# 4  37.526039  126.918643

# %%
#확인
df.loc[75634]
# Out:
# 상세영업상태코드                1
# 소재지면적               89.15
# 지번주소                 여의도동
# 사업장명              이디야라이프점
# 업태구분명                 커피숍
# 좌표정보(X)     194561.746032
# 좌표정보(Y)     446364.318286
# Name: 75634, dtype: object

# %%
df_origin[df_origin['좌표정보(X)']==0]
# Out:
#       Unnamed: 0  상세영업상태코드  소재지면적  \
# 32          2657         1  49.58
# 48          4087         2  25.31
# 127        75417         1  33.00
# 181        75567         2  25.31
# 184        75607         1    NaN
# 189        75634         1    NaN
# 223        75794         1  24.20
# 258        75873         2  24.34
# 283        75990         1  24.05
# 353        76182         1  28.43
# 354        76184         1  10.80
# 425        76363         1  38.00
# 450        76422         1  37.40
# 499        76568         1  13.76
# 547        76690         1  29.02
# 735        77125         1  19.57
# 881        77503         2  71.58
# 928        78139         2    NaN
# 929        78143         2  79.20
# 954        78525         2  31.20
# 1070       79287         2  24.79
# 1173       79673         2   8.20
# 1229       80084         2  24.25
# 1249       80237         2  24.25
# 1382       80726         2  46.80
# 1384       80728         2  37.20
# ...

# %%
len(df_origin[df_origin['좌표정보(X)']==0].index)
# Out:
# 31

# %%
#df_origin[df_origin['좌표정보(X)']==0]['좌표정보(X)']

# %%
len(df_origin[df_origin['좌표정보(X)']==0].index)
# Out:
# 31

# %%
nul2=df_origin[df_origin['좌표정보(X)']==0].index
lst=[]
for i in nul2:
  lst.append(i)
print(lst)
# Out:
# [32, 48, 127, 181, 184, 189, 223, 258, 283, 353, 354, 425, 450, 499, 547, 735, 881, 928, 929, 954, 1070, 1173, 1229, 1249, 1382, 1384, 1393, 1395, 1403, 1497, 1577]

# %%
df_origin[df_origin['좌표정보(X)']==0].index[0]
# Out:
# 32

# %%
#연습
#df.loc[n,'좌표정보(X)']= x #x바꾸기
xx=[37.5202228, 37.5342869, 37.519098, 37.5202228, 37.5202228, 37.5196175, 37.5202228, 37.5202228, 37.5196175, 
    37.5225503, 37.5196175, 37.5202228, 37.5184578, 37.5196175, 37.5196175, 37.5196175, 37.5110396, 37.5202228, 
    37.5202228, 37.52022,37.5202228,37.5349536, 37.5202228, 37.5202228, 37.52022, 37.5202228, 37.5202228, 37.5196175, 
    37.5202228, 37.5202228, 37.5196175]
yy=[126.926384, 126.901513, 126.903807, 126.926384, 126.926384, 126.939122, 126.926384, 126.926384, 126.939122, 126.931179, 
    126.939122, 126.926384, 126.903231, 126.939122, 126.939122, 126.939122, 126.910649, 126.926384, 126.926384, 126.888863, 
    126.926384, 126.901456, 126.926384, 126.926384, 126.888863, 126.926384, 126.926384, 126.939122, 126.926384, 126.926384, 
    126.939122]
df_origin.loc[df_origin[df_origin['좌표정보(X)']==0].index[0],'좌표정보(X)']= xx[0] #x바꾸기
df_origin.loc[df_origin[df_origin['좌표정보(Y)']==0].index[0],'좌표정보(Y)']= yy[0] #y바꾸기

# %%
df_origin.loc[32]
# Out:
# Unnamed: 0                           2657
# 상세영업상태코드                                1
# 소재지면적                               49.58
# 지번주소          서울특별시 영등포구 여의도동 36 롯데캐슬엠파이어
# 사업장명                    파도커피(PADO COFFEE)
# 업태구분명                                 커피숍
# 좌표정보(X)                         37.520223
# 좌표정보(Y)                        126.926384
# Name: 32, dtype: object

# %%
#위경도 좌표 널값처리 

nul2=df_origin[df_origin['좌표정보(X)']==0].index
xx=[37.5202228, 37.5342869, 37.519098, 37.5202228, 37.5202228, 37.5196175, 37.5202228, 37.5202228, 37.5196175, 
    37.5225503, 37.5196175, 37.5202228, 37.5184578, 37.5196175, 37.5196175, 37.5196175, 37.5110396, 37.5202228, 
    37.5202228, 37.52022,37.5202228,37.5349536, 37.5202228, 37.5202228, 37.52022, 37.5202228, 37.5202228, 37.5196175, 
    37.5202228, 37.5202228, 37.5196175]

yy=[126.926384, 126.901513, 126.903807, 126.926384, 126.926384, 126.939122, 126.926384, 126.926384, 126.939122, 126.931179, 
    126.939122, 126.926384, 126.903231, 126.939122, 126.939122, 126.939122, 126.910649, 126.926384, 126.926384, 126.888863, 
    126.926384, 126.901456, 126.926384, 126.926384, 126.888863, 126.926384, 126.926384, 126.939122, 126.926384, 126.926384, 
    126.939122]
# xx=[]#스프레드시트에서 긁어오기
# yy=[]#스프레드시트에서 긁어오기

for n,x,y in zip(nul2,xx,yy):
  #df.loc[1488,'소재지면적']=30
  df_origin.loc[n,'좌표정보(X)']= x #x바꾸기
  df_origin.loc[n,'좌표정보(Y)']= y #y바꾸기

#확인
#df_origin[df_origin['좌표정보(X)']==0]#아무것도안떠야 성공

# %%
df_origin[df_origin['좌표정보(X)']==0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 상세영업상태코드, 소재지면적, 지번주소, 사업장명, 업태구분명, 좌표정보(X), 좌표정보(Y)]
# Index: []

# %%
df_origin[df_origin['Unnamed: 0']==18234]
# Out:
#     Unnamed: 0  상세영업상태코드  소재지면적                                     지번주소  \
# 96       18234         1   40.1  서울특별시 영등포구 여의도동 14-21 엘지여의도에클라트 1층 104호
#
#     사업장명 업태구분명    좌표정보(X)     좌표정보(Y)
# 96  월간커피   커피숍  37.498513  127.035022

# %%
print(df_origin[df_origin['Unnamed: 0']==77141])
print(df_origin[df_origin['Unnamed: 0']==5984])
print(df_origin[df_origin['Unnamed: 0']==5888])
print(df_origin[df_origin['Unnamed: 0']==18234])
# Out:
#      Unnamed: 0  상세영업상태코드  소재지면적                              지번주소  \
# 744       77141         1   16.4  서울특별시 영등포구 여의도동 14-21 엘지여의도에클라트
#
#            사업장명 업태구분명    좌표정보(X)     좌표정보(Y)
# 744  커피온리 서여의도점   커피숍  37.498513  127.035022
#     Unnamed: 0  상세영업상태코드  소재지면적                             지번주소  \
# 86        5984         2  40.26  서울특별시 영등포구 여의도동 14-21 엘지여의도에클라트
#
#                사업장명 업태구분명    좌표정보(X)     좌표정보(Y)
# 86  롱블랙(Long Black)   커피숍  37.498513  127.035022
#     Unnamed: 0  상세영업상태코드  소재지면적                             지번주소     사업장명  \
# 85        5888         1  40.26  서울특별시 영등포구 여의도동 14-21 엘지여의도에클라트  케이팥(K팥)
#
#    업태구분명    좌표정보(X)     좌표정보(Y)
# 85   커피숍  37.498513  127.035022
#     Unnamed: 0  상세영업상태코드  소재지면적                                     지번주소  \
# 96       18234         1   40.1  서울특별시 영등포구 여의도동 14-21 엘지여의도에클라트 1층 104호
#
#     사업장명 업태구분명    좌표정보(X)     좌표정보(Y)
# 96  월간커피   커피숍  37.498513  127.035022

# %%
#221202 일단 기본정보에 대한 그래프 그리고 우도프로젝트파일에 있는 데이터프레임들 끌고오기
#목차정리,

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/미니플젝/')

# %% [markdown]
# ## df 데이터(인허가 정보)

# %%
df
# Out:
#         상세영업상태코드  소재지면적  지번주소                    사업장명 업태구분명        좌표정보(X)  \
# 3              1  11.34   문래동                  그리고 커피   커피숍  190310.553875
# 1232           1  74.00   양평동       더블플랫(DOUBLE FLAT)   커피숍  190757.977577
# 1322           1  27.56  여의도동          매머드익스프레스 여의도역점   커피숍  193209.283508
# 1334           1   5.00   문래동                   라라라핸즈   커피숍  190263.634968
# 1446           2  50.00  여의도동                    카페믹스   커피숍  192747.419300
# ...          ...    ...   ...                     ...   ...            ...
# 120786         1  24.00   문래동           토우토우(TOU TOU)   커피숍  190626.653450
# 120788         1  49.50   당산동         틈 커피(Tm coffee)   커피숍  191050.944472
# 120790         1  16.60   문래동       카페 엠아이티(Cafe MIT)   커피숍  190148.374148
# 120791         1  18.00   문래동                  브라운스케일   커피숍  189859.071769
# 120835         1  91.63   대림동  카페244 (카페다울 한국상하수도협회점)   커피숍  190819.186099
#
#               좌표정보(Y)
# 3       446496.894116
# ...

# %% [markdown]
# ## dong 데이터 (상권분석시스템)

# %%
dong
# Out:
#        동 동 자세히  매출(만원)   업소갯수
# 0    신길동    1동  1727.0   12.0
# 1    신길동    2동  1497.0   35.0
# 2    신길동    3동   399.0   17.0
# 3    신길동    4동   444.0   14.0
# 4    신길동    5동   846.0   11.0
# 5    신길동    6동  1446.0   27.0
# 6    신길동    7동  1546.0   10.0
# 7    당산동    1동  1264.0   79.0
# 8    당산동    2동  1947.0   66.0
# 9   영등포동  영등포동  1440.0  114.0
# 10  여의도동  여의도동  2197.0  238.0
# 11   문래동   문래동  1805.0   93.0
# 12   양평동    1동   870.0   51.0
# 13   양평동    2동   801.0   72.0
# 14   대림동    1동  1643.0   16.0
# 15   대림동    2동  2063.0    9.0
# 16   대림동    3동  1504.0   35.0
# 17   도림동   도림동  1755.0   20.0

# %% [markdown]
# ## 하이테크시티 데이터

# %%
hitech = pd.read_csv('Hitech_shop.csv',header=None)
hitech
# Out:
#        0                   1             2
# 0    NaN                   0  1.000000e+00
# 1    0.0      문래동 커피숍 월평균 매출  1.805000e+07
# 2    1.0      문래동 커피숍 일평균 매출  9.250000e+04
# 3    2.0      문래동 커피숍 평균 커피값  4.208000e+03
# 4    3.0  문래동 커피숍 일평균 컵 배출량   2.140000e+02
# 5    4.0    하이테크 커피숍 일 평균 매출  7.220000e+06
# 6    5.0   하이테크 일 평균 컵 배출 수량  1.716000e+03
# 7    6.0   하이테크 월 평균 컵 배출 수량  3.431600e+04
# 8    7.0   하이테크 연 평균 컵 배출 수량  4.117870e+05
# 9    8.0     플라스틱 커피 컵 1개 무게  1.200000e-02
# 10   9.0     하이테크 일 평균 컵 배출량  2.100000e+01
# 11  10.0     하이테크 월 평균 컵 배출량  4.120000e+02
# 12  11.0     하이테크 연 평균 컵 배출량  4.941000e+03

# %%
#hitech=hitech.drop([2,3],axis=1)
#hitech.loc[8,1]=0.012
# hitech[1]=round(hitech[1].astype(float),3)
# hitech.loc[8,1]=0.012
# hitech
# pd.options.display.float_format='{:.3f}'.format
# hitech

# %% [markdown]
# ## 우도 데이터(기사 참조 및 상권분석 시스템)

# %%
udo = pd.read_csv('우도 연간 생활폐기물 배출량.csv',index_col=0)
udo
# Out:
#              2019   2020   2021
# Unnamed: 0
# 1월           52.2   51.0   48.0
# 2월           42.8   42.0   52.1
# 3월           42.5   26.0   46.3
# 4월           81.0   54.4   64.9
# 5월           84.4   62.0   68.2
# 6월           80.0   76.0   71.4
# 7월          115.6   92.1   98.1
# 8월          125.3   97.2   97.4
# 9월           84.7   85.0   74.0
# 10월          80.3   67.8   68.1
# 11월          53.0   60.4   42.2
# 12월          53.2   58.0   34.8
# 연 총합        895.0  771.9  765.5
# 월간 컵 배출량     23.4   23.4   23.4

# %% [markdown]
# ## 동별 매출로 산출한 플라스틱 컵 배출량

# %%
cup = pd.read_excel('동별 전체 매출 산출.xlsx')
cup
# Out:
#       동  월매출(만원)   업소갯수  월 배출 수량  월 배출량(kg)
# 0   신길동  1524.57  174.0   631307   7575.684
# 1   당산동  1605.50  240.0   916992  11003.904
# 2  영등포동  1440.00  286.0   980105  11761.260
# 3  여의도동  2197.00  478.0  2499205  29990.460
# 4   문래동  1805.00  155.0   665814   7989.768
# 5   양평동   835.50  152.0   302228   3626.736
# 6   대림동  1736.66   94.0   388496   4661.952
# 7   도림동  1755.00   34.0   142004   1704.048

# %% [markdown]
# ## 우도vs 영등포구
#
# *   항목 추가
# *   항목 추가

# %%
si=pd.read_csv('우도영등포구기본정보.csv')
si
# Out:
#   Unnamed: 0  면적(km²)     인구수    유동인구수
# 0         우도     6.18    1722    29069
# 1       영등포구    24.56  375849  2780000

# %%
si.columns[1]
#si[1]
# Out:
# '면적(km²)'

# %%
#우도vs영등포 기본정보 시각화->슬렉에 공유 
plt.rcParams['figure.figsize'] = [15, 20] # [width, height] (inches)
#plt.figure(figsize=(10,5))
for i in range(1,4):
  plt.subplot(2,3,i)
  sns.barplot(data=si,x='Unnamed: 0', y=si.columns[i])
  plt.xlabel(si.columns[i])
  plt.ylabel('')
  #피피티에서 수정하기 글씨 잘림
  #중간에 자를수 있는지
  # plt.text(0,si.loc[0,si.columns[i]]+2, si.loc[0,si.columns[i]], va='center',ha='center',fontsize=20)
  # plt.text(1,si.loc[1,si.columns[i]]-1, si.loc[1,si.columns[i]], va='center',ha='center',fontsize=20)
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50864 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54252 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import folium
import json #자바스크립트오브젝트 노테이션 -웹페이지상 어쩌구

#5-22. 서울지역 구별 boundary 시각화
#base map
bk_m = folium.Map(location=[37.541, 126.986], zoom_start=11)  # 위도,경도 37.541° 126.986

folium.Marker(location=[37.541, 126.986],
              ).add_to(bk_m)
bk_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df_si=df_origin.copy()
df_si.head()
# Out:
#    Unnamed: 0  상세영업상태코드  소재지면적  \
# 0           3         1  11.34
# 1        1232         1  74.00
# 2        1322         1  27.56
# 3        1334         1   5.00
# 4        1446         2  50.00
#
#                                                지번주소               사업장명 업태구분명  \
# 0                             서울특별시 영등포구 문래동3가 82-3             그리고 커피   커피숍
# 1                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌  더블플랫(DOUBLE FLAT)   커피숍
# 2                           서울특별시 영등포구 여의도동 37 아일렉스     매머드익스프레스 여의도역점   커피숍
# 3                              서울특별시 영등포구 문래동4가 7-1              라라라핸즈   커피숍
# 4  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)                카페믹스   커피숍
#
#      좌표정보(X)     좌표정보(Y)
# 0  37.520618  126.891165
# 1  37.535550  126.896113
# 2  37.521024  126.924012
# 3  37.516095  126.890646
# 4  37.526039  126.918643

# %%
#동별로 나눠주기->아 그럴 필요가 없네..->df에 널값을 채워주고 문래동 그리고커피 라고 하던가-> 근데 주소를 안 넣어도 될거같다.->df로 하자
#지도에 표시할것:동,까페이름 
#df_origin의 사용은 위경도 널값처리하는데 사용하였다. 
#지도에 표시:지번주소,사업장명
#필요한것 좌표정보 좌표정보(X)	좌표정보(Y)(헐.. 엑스와이 왜 안바뀜 이거 런타임전체재생 안함?)
#그러면 그냥 오리진에 새로 붙이자 ㅇㅋ
#
df_si.head()
# Out:
#    Unnamed: 0  상세영업상태코드  소재지면적  \
# 0           3         1  11.34
# 1        1232         1  74.00
# 2        1322         1  27.56
# 3        1334         1   5.00
# 4        1446         2  50.00
#
#                                                지번주소               사업장명 업태구분명  \
# 0                             서울특별시 영등포구 문래동3가 82-3             그리고 커피   커피숍
# 1                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌  더블플랫(DOUBLE FLAT)   커피숍
# 2                           서울특별시 영등포구 여의도동 37 아일렉스     매머드익스프레스 여의도역점   커피숍
# 3                              서울특별시 영등포구 문래동4가 7-1              라라라핸즈   커피숍
# 4  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)                카페믹스   커피숍
#
#      좌표정보(X)     좌표정보(Y)
# 0  37.520618  126.891165
# 1  37.535550  126.896113
# 2  37.521024  126.924012
# 3  37.516095  126.890646
# 4  37.526039  126.918643

# %%
#sp = df['지번주소'].str.split(' ',n=3,expand=True)
#d = sp[2].apply(lambda x: x.split('동')[0]+'동')

# %%
df_si.head()
# Out:
#    Unnamed: 0  상세영업상태코드  소재지면적  \
# 0           3         1  11.34
# 1        1232         1  74.00
# 2        1322         1  27.56
# 3        1334         1   5.00
# 4        1446         2  50.00
#
#                                                지번주소               사업장명 업태구분명  \
# 0                             서울특별시 영등포구 문래동3가 82-3             그리고 커피   커피숍
# 1                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌  더블플랫(DOUBLE FLAT)   커피숍
# 2                           서울특별시 영등포구 여의도동 37 아일렉스     매머드익스프레스 여의도역점   커피숍
# 3                              서울특별시 영등포구 문래동4가 7-1              라라라핸즈   커피숍
# 4  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)                카페믹스   커피숍
#
#      좌표정보(X)     좌표정보(Y)
# 0  37.520618  126.891165
# 1  37.535550  126.896113
# 2  37.521024  126.924012
# 3  37.516095  126.890646
# 4  37.526039  126.918643

# %%
df_si['지번주소1']=df['지번주소'].str.split(' ',expand=True)
df_si.head()
# Out:
#    Unnamed: 0  상세영업상태코드  소재지면적  \
# 0           3         1  11.34
# 1        1232         1  74.00
# 2        1322         1  27.56
# 3        1334         1   5.00
# 4        1446         2  50.00
#
#                                                지번주소               사업장명 업태구분명  \
# 0                             서울특별시 영등포구 문래동3가 82-3             그리고 커피   커피숍
# 1                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌  더블플랫(DOUBLE FLAT)   커피숍
# 2                           서울특별시 영등포구 여의도동 37 아일렉스     매머드익스프레스 여의도역점   커피숍
# 3                              서울특별시 영등포구 문래동4가 7-1              라라라핸즈   커피숍
# 4  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)                카페믹스   커피숍
#
#      좌표정보(X)     좌표정보(Y) 지번주소1
# 0  37.520618  126.891165   NaN
# 1  37.535550  126.896113   NaN
# 2  37.521024  126.924012   NaN
# 3  37.516095  126.890646   문래동
# 4  37.526039  126.918643   NaN

# %%
df_si.drop('지번주소1',axis=1, inplace=True)
df_si
# Out:
#       Unnamed: 0  상세영업상태코드  소재지면적  \
# 0              3         1  11.34
# 1           1232         1  74.00
# 2           1322         1  27.56
# 3           1334         1   5.00
# 4           1446         2  50.00
# ...          ...       ...    ...
# 1610      120786         1  24.00
# 1611      120788         1  49.50
# 1612      120790         1  16.60
# 1613      120791         1  18.00
# 1614      120835         1  91.63
#
#                                                   지번주소  \
# 0                                서울특별시 영등포구 문래동3가 82-3
# 1                         서울특별시 영등포구 양평동4가 51-1 경남아너스빌
# 2                              서울특별시 영등포구 여의도동 37 아일렉스
# 3                                 서울특별시 영등포구 문래동4가 7-1
# 4     서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)
# ...                                                ...
# 1610                             서울특별시 영등포구 문래동2가 17-1
# 1611                              서울특별시 영등포구 당산동1가 238
# ...

# %%
sp = df['지번주소'].str.split(' ',expand=True)
sp
# Out:
#            0
# 3        문래동
# 1232     양평동
# 1322    여의도동
# 1334     문래동
# 1446    여의도동
# ...      ...
# 120786   문래동
# 120788   당산동
# 120790   문래동
# 120791   문래동
# 120835   대림동
#
# [1613 rows x 1 columns]

# %%
df_origin.columns
# Out:
# Index(['Unnamed: 0', '상세영업상태코드', '소재지면적', '지번주소', '사업장명', '업태구분명', '좌표정보(X)',
#        '좌표정보(Y)'],
#       dtype='object')

# %%
#df_origin 인덱스 다시 넣어준 후 적용시켜보기
df_si=df_origin.set_index('Unnamed: 0')
df_si.head()
# df_si['지번주소1']=sp
# df_si.head()
# #왜 내꺼는 인덱스 넘버가 빼져있지 다시 처음부터 실행해볼까?(index_col=해야됨)#
# Out:
#             상세영업상태코드  소재지면적                                              지번주소  \
# Unnamed: 0
# 3                  1  11.34                             서울특별시 영등포구 문래동3가 82-3
# 1232               1  74.00                      서울특별시 영등포구 양평동4가 51-1 경남아너스빌
# 1322               1  27.56                           서울특별시 영등포구 여의도동 37 아일렉스
# 1334               1   5.00                              서울특별시 영등포구 문래동4가 7-1
# 1446               2  50.00  서울특별시 영등포구 여의도동 17번지 더?아일랜드파크 지상1층 102-106호(전체)
#
#                          사업장명 업태구분명    좌표정보(X)     좌표정보(Y)
# Unnamed: 0
# 3                      그리고 커피   커피숍  37.520618  126.891165
# 1232        더블플랫(DOUBLE FLAT)   커피숍  37.535550  126.896113
# 1322           매머드익스프레스 여의도역점   커피숍  37.521024  126.924012
# 1334                    라라라핸즈   커피숍  37.516095  126.890646
# 1446                     카페믹스   커피숍  37.526039  126.918643

# %%
df_si['지번주소']=sp
df_si.head()


#여기서 이제 폴리움을
#지번주소, 사업장명 이렇게 지도에 나타내야 한다.
#그룹화를 하자.
# Out:
#             상세영업상태코드  소재지면적  지번주소               사업장명 업태구분명    좌표정보(X)  \
# Unnamed: 0
# 3                  1  11.34   문래동             그리고 커피   커피숍  37.520618
# 1232               1  74.00   양평동  더블플랫(DOUBLE FLAT)   커피숍  37.535550
# 1322               1  27.56  여의도동     매머드익스프레스 여의도역점   커피숍  37.521024
# 1334               1   5.00   문래동              라라라핸즈   커피숍  37.516095
# 1446               2  50.00  여의도동               카페믹스   커피숍  37.526039
#
#                좌표정보(Y)
# Unnamed: 0
# 3           126.891165
# 1232        126.896113
# 1322        126.924012
# 1334        126.890646
# 1446        126.918643

# %%
df_si['자치구']='영등포구'
df_si
# Out:
#             상세영업상태코드  소재지면적  지번주소                    사업장명 업태구분명    좌표정보(X)  \
# Unnamed: 0
# 3                  1  11.34   문래동                  그리고 커피   커피숍  37.520618
# 1232               1  74.00   양평동       더블플랫(DOUBLE FLAT)   커피숍  37.535550
# 1322               1  27.56  여의도동          매머드익스프레스 여의도역점   커피숍  37.521024
# 1334               1   5.00   문래동                   라라라핸즈   커피숍  37.516095
# 1446               2  50.00  여의도동                    카페믹스   커피숍  37.526039
# ...              ...    ...   ...                     ...   ...        ...
# 120786             1  24.00   문래동           토우토우(TOU TOU)   커피숍  37.512976
# 120788             1  49.50   당산동         틈 커피(Tm coffee)   커피숍  37.522951
# 120790             1  16.60   문래동       카페 엠아이티(Cafe MIT)   커피숍  37.518441
# 120791             1  18.00   문래동                  브라운스케일   커피숍  37.514834
# 120835             1  91.63   대림동  카페244 (카페다울 한국상하수도협회점)   커피숍  37.502487
#
#                좌표정보(Y)   자치구
# Unnamed: 0
# ...

# %%
#!pip install folium

# %%
import folium
import json #자바스크립트오브젝트 노테이션 -웹페이지상 어쩌구

# %%
# 5-17. 서울 행정구역 json raw파일, skorea_municipalities_geo_simple.json
geo_path = 'skorea_municipalities_geo_simple.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))  #json 파일==> 딕셔너리로 거쳐줘야 사용가능

#위작업 제이슨을 딕셔너리 형태로 바꿔주는작업이었다

# %%
#5-18. key값만 출력

geo_str.keys()
# Out:
# dict_keys(['type', 'features'])

# %%
geo_str['features']
# Out:
# [{'type': 'Feature',
#   'properties': {'code': '39020',
#    'name': '서귀포시',
#    'name_eng': 'Seogwipo-si',
#    'base_year': '2013'},
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[126.1701670531016, 33.27833920373795],
#      [126.17796199822318, 33.28904450342792],
#      [126.20366562455006, 33.292582069125935],
#      [126.23227804627976, 33.28054651709448],
#      [126.27081469983565, 33.29305651947374],
#      [126.28692516789717, 33.3095121006344],
#      [126.32582807936741, 33.32307849544494],
#      [126.33863040850332, 33.33700002289742],
#      [126.37692773779688, 33.34348978209229],
#      [126.42008790072302, 33.33448285889923],
#      [126.43967991919219, 33.34042205120408],
#      [126.44742456956253, 33.35529267692266],
#      [126.4918716225209, 33.351283204155564],
#      [126.54001194569452, 33.35949354681064],
#      [126.55310458705854, 33.368769331336765],
#      [126.5830715764017, 33.368027779973275],
# ...

# %%
# !pip install geopandas #다시 설치해야해?
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.1 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 16.6 MB 51.6 MB/s
# ...
#      |████████████████████████████████| 7.8 MB 34.4 MB/s
# ...

# %%
import geopandas as gpd

# %%
#5-20. read_file로 geo_path를 읽어옴
#https://ko.wikipedia.org/wiki/GeoJSON
import geopandas as gpd

geoJSON_df = gpd.read_file(geo_path)
geoJSON_df.head()
# Out:
#     code  name      name_eng base_year  \
# 0  39020  서귀포시   Seogwipo-si      2013
# 1  39010   제주시       Jeju-si      2013
# 2  38400   합천군  Hapcheon-gun      2013
# 3  38390   거창군  Geochang-gun      2013
# 4  38380   함양군   Hamyang-gun      2013
#
#                                             geometry
# 0  POLYGON ((126.17017 33.27834, 126.17796 33.289...
# 1  MULTIPOLYGON (((126.95749 33.52246, 126.97320 ...
# 2  POLYGON ((128.16625 35.77402, 128.16647 35.759...
# 3  POLYGON ((128.08089 35.83593, 128.09286 35.827...
# 4  POLYGON ((127.68118 35.76626, 127.71167 35.744...

# %%
#5-21. 'code'의 앞2자리만 추출해서 데이터와 데이터수확인, value_counts(), sort_index()
geoJSON_df['code'].str[:2].value_counts().sort_index()
# Out:
# 11    25
# 21    16
# 22     8
# 23    10
# 24     5
# 25     5
# 26     5
# 29     1
# 31    44
# 32    18
# 33    13
# 34    16
# 35    15
# 36    22
# 37    24
# 38    22
# 39     2
# Name: code, dtype: int64

# %%
#일단 서울인것만 불러줬어.
geoJSON_df = geoJSON_df.loc[geoJSON_df['code'].str[:2]=='11'] 

geoJSON_df
# Out:
#       code  name         name_eng base_year  \
# 226  11250   강동구      Gangdong-gu      2013
# 227  11240   송파구        Songpa-gu      2013
# 228  11230   강남구       Gangnam-gu      2013
# 229  11220   서초구        Seocho-gu      2013
# 230  11210   관악구        Gwanak-gu      2013
# 231  11200   동작구       Dongjak-gu      2013
# 232  11190  영등포구  Yeongdeungpo-gu      2013
# 233  11180   금천구     Geumcheon-gu      2013
# 234  11170   구로구          Guro-gu      2013
# 235  11160   강서구       Gangseo-gu      2013
# 236  11150   양천구     Yangcheon-gu      2013
# 237  11140   마포구          Mapo-gu      2013
# 238  11130  서대문구     Seodaemun-gu      2013
# 239  11120   은평구     Eunpyeong-gu      2013
# 240  11110   노원구         Nowon-gu      2013
# 241  11100   도봉구        Dobong-gu      2013
# 242  11090   강북구       Gangbuk-gu      2013
# 243  11080   성북구      Seongbuk-gu      2013
# 244  11070   중랑구      Jungnang-gu      2013
# 245  11060  동대문구    Dongdaemun-gu      2013
# ...

# %%
#5-22. 영등포 지도만 띄우기(그냥확인용)
#base map
bk_m = folium.Map(location=[37.526359, 126.933522], zoom_start=11)  # 위도,경도 37.541° 126.986

folium.Marker(location=[37.526359, 126.933522],
              ).add_to(bk_m)
bk_m

#37.526359
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#geo_str.keys()
geo_str['features'][0]
# Out:
# {'type': 'Feature',
#  'properties': {'code': '39020',
#   'name': '서귀포시',
#   'name_eng': 'Seogwipo-si',
#   'base_year': '2013'},
#  'geometry': {'type': 'Polygon',
#   'coordinates': [[[126.1701670531016, 33.27833920373795],
#     [126.17796199822318, 33.28904450342792],
#     [126.20366562455006, 33.292582069125935],
#     [126.23227804627976, 33.28054651709448],
#     [126.27081469983565, 33.29305651947374],
#     [126.28692516789717, 33.3095121006344],
#     [126.32582807936741, 33.32307849544494],
#     [126.33863040850332, 33.33700002289742],
#     [126.37692773779688, 33.34348978209229],
#     [126.42008790072302, 33.33448285889923],
#     [126.43967991919219, 33.34042205120408],
#     [126.44742456956253, 33.35529267692266],
#     [126.4918716225209, 33.351283204155564],
#     [126.54001194569452, 33.35949354681064],
#     [126.55310458705854, 33.368769331336765],
#     [126.5830715764017, 33.368027779973275],
#     [126.65655971322707, 33.39658294968576],
# ...

# %%
df_si['지번주소'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of Unnamed: 0
# 3          문래동
# 1232       양평동
# 1322      여의도동
# 1334       문래동
# 1446      여의도동
#           ...
# 120786     문래동
# 120788     당산동
# 120790     문래동
# 120791     문래동
# 120835     대림동
# Name: 지번주소, Length: 1615, dtype: object>

# %%
#목적:지도에 색깔 칠하기
df_si_gu=df_si.groupby('지번주소').count()[['사업장명']]#head()
df_si_gu
# Out:
#       사업장명
# 지번주소
# 당산동    240
# 대림동     94
# 도림동     34
# 문래동    155
# 신길동    174
# 양평동    152
# 여의도동   478
# 영등포동   286

# %%
#인덱스를 칼럼으로 빼주는 작업
df_si_gu2 = df_si_gu.reset_index()
df_si_gu2
# Out:
#    지번주소  사업장명
# 0   당산동   240
# 1   대림동    94
# 2   도림동    34
# 3   문래동   155
# 4   신길동   174
# 5   양평동   152
# 6  여의도동   478
# 7  영등포동   286

# %%
df_si_gu2
# Out:
#    지번주소  사업장명
# 0   당산동   240
# 1   대림동    94
# 2   도림동    34
# 3   문래동   155
# 4   신길동   174
# 5   양평동   152
# 6  여의도동   478
# 7  영등포동   286

# %%
df_si_gu2.columns
# Out:
# Index(['지번주소', '사업장명'], dtype='object')

# %%
#하고싶은것:영등포구의 면적만 나타내주기->안되면 마커만 하기 ㅇㅋ
#안되는 이유->자전거는 서울시의 폴리움 그래서 동별 세분화불가능
#하고싶은것은 영등포구 동별 
#이거 일단 안되니까 클러스터 마커 표시만
#geoJSON_df우리가 들고온 지도

#이거 안되는 이유 이건 위경도 표시 없어 우린 서울시만 있다구 그래서 안될수밖에 없는 패스

# %%
#df_si좌표정보(X) 좌표정보(Y)
#df_si_gu2 색칠을 위한 파일생성

# %%
df_si.head()
# Out:
#             상세영업상태코드  소재지면적  지번주소               사업장명 업태구분명    좌표정보(X)  \
# Unnamed: 0
# 3                  1  11.34   문래동             그리고 커피   커피숍  37.520618
# 1232               1  74.00   양평동  더블플랫(DOUBLE FLAT)   커피숍  37.535550
# 1322               1  27.56  여의도동     매머드익스프레스 여의도역점   커피숍  37.521024
# 1334               1   5.00   문래동              라라라핸즈   커피숍  37.516095
# 1446               2  50.00  여의도동               카페믹스   커피숍  37.526039
#
#                좌표정보(Y)   자치구
# Unnamed: 0
# 3           126.891165  영등포구
# 1232        126.896113  영등포구
# 1322        126.924012  영등포구
# 1334        126.890646  영등포구
# 1446        126.918643  영등포구

# %%
#안된이유:리셋인덱스 오케
df_si_gu2 = df_si_gu.reset_index()
df_si_gu2
# Out:
#    지번주소  사업장명
# 0   당산동   240
# 1   대림동    94
# 2   도림동    34
# 3   문래동   155
# 4   신길동   174
# 5   양평동   152
# 6  여의도동   478
# 7  영등포동   286

# %%
df_si2=df_si.reset_index()
df_si2.head()
# Out:
#    Unnamed: 0  상세영업상태코드  소재지면적  지번주소               사업장명 업태구분명    좌표정보(X)  \
# 0           3         1  11.34   문래동             그리고 커피   커피숍  37.520618
# 1        1232         1  74.00   양평동  더블플랫(DOUBLE FLAT)   커피숍  37.535550
# 2        1322         1  27.56  여의도동     매머드익스프레스 여의도역점   커피숍  37.521024
# 3        1334         1   5.00   문래동              라라라핸즈   커피숍  37.516095
# 4        1446         2  50.00  여의도동               카페믹스   커피숍  37.526039
#
#       좌표정보(Y)   자치구
# 0  126.891165  영등포구
# 1  126.896113  영등포구
# 2  126.924012  영등포구
# 3  126.890646  영등포구
# 4  126.918643  영등포구

# %%
df_si2.loc[0, "좌표정보(X)"]
# Out:
# 37.520618

# %%
#일단성공
bk_m = folium.Map(location=[37.526359, 126.933522], zoom_start=11)  # 위도,경도 37.541° 126.986

bk_lat = df_si2.loc[0, "좌표정보(X)"]
bk_long = df_si2.loc[0, "좌표정보(Y)"]

folium.Marker(location=[37.526359, 126.933522],
              ).add_to(bk_m)
bk_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df_si2.head()
# Out:
#    Unnamed: 0  상세영업상태코드  소재지면적  지번주소               사업장명 업태구분명    좌표정보(X)  \
# 0           3         1  11.34   문래동             그리고 커피   커피숍  37.520618
# 1        1232         1  74.00   양평동  더블플랫(DOUBLE FLAT)   커피숍  37.535550
# 2        1322         1  27.56  여의도동     매머드익스프레스 여의도역점   커피숍  37.521024
# 3        1334         1   5.00   문래동              라라라핸즈   커피숍  37.516095
# 4        1446         2  50.00  여의도동               카페믹스   커피숍  37.526039
#
#       좌표정보(Y)   자치구
# 0  126.891165  영등포구
# 1  126.896113  영등포구
# 2  126.924012  영등포구
# 3  126.890646  영등포구
# 4  126.918643  영등포구

# %%
#팝업오류 일단 포문부터 해보기 
from folium.plugins import MarkerCluster
#[37.526359, 126.933522]
m = folium.Map(location=[37.5502, 126.982], zoom_start=11.5)

mc = MarkerCluster().add_to(m)
#df_si좌표정보(X)	좌표정보(Y)

#하나만 넣어볼까?
bk_lat = df_si2.loc[0, "좌표정보(X)"]
bk_long = df_si2.loc[0, "좌표정보(Y)"]
gu = df_si2.loc[0,'자치구']
don = df_si2.loc[0,'지번주소']
#cnt = bk_df1.loc[i,'총거치대수']
name = df_si2.loc[0,'사업장명']
folium.Marker(
    [bk_lat,bk_long], 
    title = f'{don} : {name}',
    #popup=f'<i>{title}</i>', #뭔차이지
    tooltip=f'{don}-{name}').add_to(mc)

bk_m = folium.Map(location=[37.526359, 126.933522], zoom_start=11)  # 위도,경도 37.541° 126.986

bk_lat = df_si2.loc[0, "좌표정보(X)"]
bk_long = df_si2.loc[0, "좌표정보(Y)"]

folium.Marker(location=[37.526359, 126.933522],
              ).add_to(bk_m)
bk_m



#37.526359
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#일단 현재까지 이것
#팝업성공->두개성공->여기까지 되면 클러스터 해보기 
from folium import Marker
Marker(location = [df_si2.loc[0, "좌표정보(X)"], df_si2.loc[0, "좌표정보(Y)"]],
           popup=df_si2.loc[0,'사업장명'],
           icon=folium.Icon(color='blue',icon='star')
          ).add_to(m)

Marker(location = [df_si2.loc[1, "좌표정보(X)"], df_si2.loc[1, "좌표정보(Y)"]],
           popup= df_si2.loc[1,'사업장명'],
           icon=folium.Icon(color='blue',icon='star')
          ).add_to(m)
m      
#안되니까 이름만 뜨게 하자 오케이
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#팝업성공->두개성공->여기까지 되면 클러스터 해보기 
don = df_si2.loc[5,'지번주소']
name = df_si2.loc[5,'사업장명']

Marker(location = [df_si2.loc[5, "좌표정보(X)"], df_si2.loc[5, "좌표정보(Y)"]],
       popup= df_si2.loc[5,'사업장명'],
       #icon=folium.Icon(color='blue',icon='star'),#클릭-얘를 빼자
       tooltip=f'{don}-{name}').add_to(m)#마우스커서

don = df_si2.loc[1,'지번주소']
name = df_si2.loc[1,'사업장명']

Marker(location = [df_si2.loc[1, "좌표정보(X)"], df_si2.loc[1, "좌표정보(Y)"]],
       popup= df_si2.loc[1,'사업장명'],
       #icon=folium.Icon(color='blue',icon='star'),#클릭-얘를 빼자
       tooltip=f'{don}-{name}').add_to(m)#마우스커서

m      
#안되니까 이름만 뜨게 하자 오케이
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df_si2.tail()
# Out:
#       Unnamed: 0  상세영업상태코드  소재지면적 지번주소                    사업장명 업태구분명  \
# 1610      120786         1  24.00  문래동           토우토우(TOU TOU)   커피숍
# 1611      120788         1  49.50  당산동         틈 커피(Tm coffee)   커피숍
# 1612      120790         1  16.60  문래동       카페 엠아이티(Cafe MIT)   커피숍
# 1613      120791         1  18.00  문래동                  브라운스케일   커피숍
# 1614      120835         1  91.63  대림동  카페244 (카페다울 한국상하수도협회점)   커피숍
#
#         좌표정보(X)     좌표정보(Y)   자치구
# 1610  37.512976  126.894816  영등포구
# 1611  37.522951  126.899534  영등포구
# 1612  37.518441  126.889342  영등포구
# 1613  37.514834  126.886047  영등포구
# 1614  37.502487  126.896891  영등포구

# %%
#팝업성공->두개성공->여기까지 되면 클러스터 해보기 
don = df_si2.loc[5,'지번주소']
name = df_si2.loc[5,'사업장명']

Marker(location = [df_si2.loc[5, "좌표정보(X)"], df_si2.loc[5, "좌표정보(Y)"]],
       popup= df_si2.loc[5,'사업장명'],
       #icon=folium.Icon(color='blue',icon='star'),#클릭-얘를 빼자
       tooltip=f'{don}-{name}').add_to(m)#마우스커서

don = df_si2.loc[1,'지번주소']
name = df_si2.loc[1,'사업장명']

Marker(location = [df_si2.loc[1, "좌표정보(X)"], df_si2.loc[1, "좌표정보(Y)"]],
       popup= df_si2.loc[1,'사업장명'],
       #icon=folium.Icon(color='blue',icon='star'),#클릭-얘를 빼자
       tooltip=f'{don}-{name}').add_to(m)#마우스커서
don = df_si2.loc[11,'지번주소']
name = df_si2.loc[11,'사업장명']

Marker(location = [df_si2.loc[11, "좌표정보(X)"], df_si2.loc[11, "좌표정보(Y)"]],
       popup= df_si2.loc[11,'사업장명'],
       #icon=folium.Icon(color='blue',icon='star'),#클릭-얘를 빼자
       tooltip=f'{don}-{name}').add_to(m)#마우스커서

m      
#안되니까 이름만 뜨게 하자 오케이
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 저이제 포문 도전합니다
from folium import Marker
#팝업성공->두개성공->여기까지 되면 클러스터 해보기 
m = folium.Map(location=[37.526359, 126.933522], zoom_start=11) 
for i in range(100):
  don = df_si2.loc[i,'지번주소']
  name = df_si2.loc[i,'사업장명']
  Marker(location = [df_si2.loc[i, "좌표정보(X)"], df_si2.loc[i, "좌표정보(Y)"]],
         popup= name,
         #icon=folium.Icon(color='blue',icon='star'),#클릭-얘를 빼자
         tooltip=f'{don}-{name}').add_to(m)#마우스커서

# don = df_si2.loc[1,'지번주소']
# name = df_si2.loc[1,'사업장명']

# Marker(location = [df_si2.loc[1, "좌표정보(X)"], df_si2.loc[1, "좌표정보(Y)"]],
#        popup= df_si2.loc[1,'사업장명'],
#        #icon=folium.Icon(color='blue',icon='star'),#클릭-얘를 빼자
#        tooltip=f'{don}-{name}').add_to(m)#마우스커서

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
len(df_si2)
# Out:
# 1615

# %%
df_si2.isna().sum()
# Out:
# Unnamed: 0     0
# 상세영업상태코드       0
# 소재지면적         28
# 지번주소           2
# 사업장명           0
# 업태구분명          0
# 좌표정보(X)        0
# 좌표정보(Y)        0
# 자치구            0
# dtype: int64

# %%
#454,455
df_si2.loc[454]
# Out:
# Unnamed: 0                  76432
# 상세영업상태코드                        1
# 소재지면적                         9.9
# 지번주소                         여의도동
# 사업장명          인하스빈스(Inha`s Beans)
# 업태구분명                         커피숍
# 좌표정보(X)                 37.520761
# 좌표정보(Y)                126.926893
# 자치구                          영등포구
# Name: 454, dtype: object

# %%
#밑에 오류난것 잡기. ->문제발생 454가 어그러진다. 
#df_si2=df_si2.drop('454')
df_si2=df_si2.drop(454,axis='rows')

# %%
df_si2.shape
# Out:
# (1614, 9)

# %%
df_si3 = df_si2.reset_index()
df_si3.head()
# Out:
#    index  Unnamed: 0  상세영업상태코드  소재지면적  지번주소               사업장명 업태구분명  \
# 0      0           3         1  11.34   문래동             그리고 커피   커피숍
# 1      1        1232         1  74.00   양평동  더블플랫(DOUBLE FLAT)   커피숍
# 2      2        1322         1  27.56  여의도동     매머드익스프레스 여의도역점   커피숍
# 3      3        1334         1   5.00   문래동              라라라핸즈   커피숍
# 4      4        1446         2  50.00  여의도동               카페믹스   커피숍
#
#      좌표정보(X)     좌표정보(Y)   자치구
# 0  37.520618  126.891165  영등포구
# 1  37.535550  126.896113  영등포구
# 2  37.521024  126.924012  영등포구
# 3  37.516095  126.890646  영등포구
# 4  37.526039  126.918643  영등포구

# %%
df_si3.loc[[455]] #확인완료
# Out:
#      index  Unnamed: 0  상세영업상태코드  소재지면적  지번주소         사업장명 업태구분명   좌표정보(X)  \
# 455    456       76444         1   27.7  영등포동  행복두드리미버드나루점   커피숍  37.52035
#
#         좌표정보(Y)   자치구
# 455  126.913598  영등포구

# %%
df_si3.columns
# Out:
# Index(['index', 'Unnamed: 0', '상세영업상태코드', '소재지면적', '지번주소', '사업장명', '업태구분명',
#        '좌표정보(X)', '좌표정보(Y)', '자치구'],
#       dtype='object')

# %%
df_si3.shape
# Out:
# (1614, 10)

# %%
df_si2.head()
# Out:
#    Unnamed: 0  상세영업상태코드  소재지면적  지번주소               사업장명 업태구분명    좌표정보(X)  \
# 0           3         1  11.34   문래동             그리고 커피   커피숍  37.520618
# 1        1232         1  74.00   양평동  더블플랫(DOUBLE FLAT)   커피숍  37.535550
# 2        1322         1  27.56  여의도동     매머드익스프레스 여의도역점   커피숍  37.521024
# 3        1334         1   5.00   문래동              라라라핸즈   커피숍  37.516095
# 4        1446         2  50.00  여의도동               카페믹스   커피숍  37.526039
#
#       좌표정보(Y)   자치구
# 0  126.891165  영등포구
# 1  126.896113  영등포구
# 2  126.924012  영등포구
# 3  126.890646  영등포구
# 4  126.918643  영등포구

# %%
#
df_si3.loc[1270]
# Out:
# index               1271
# Unnamed: 0         80339
# 상세영업상태코드               2
# 소재지면적              29.45
# 지번주소                여의도동
# 사업장명            인산죽염원광센터
# 업태구분명                커피숍
# 좌표정보(X)        37.517961
# 좌표정보(Y)       126.932864
# 자치구                 영등포구
# Name: 1270, dtype: object

# %%
#인덱스번호추출
df_si3[df_si3['사업장명']=='윙스커피(wing`s coffee)']
# Out:
#       index  Unnamed: 0  상세영업상태코드  소재지면적 지번주소                 사업장명 업태구분명  \
# 1269   1270       80338         2   43.0  양평동  윙스커피(wing`s coffee)   커피숍
#
#         좌표정보(X)     좌표정보(Y)   자치구
# 1269  37.535791  126.897355  영등포구

# %%
#특수문자 1개, 잘못된 좌표4개 드랍해주기
#df_si3[df_si3['사업장명']=='윙스커피(wing`s coffee)'] #1269
#df_si3[df_si3['사업장명']=='커피온리 서여의도점'] #743
#df_si3[df_si3['사업장명']=='롱블랙(Long Black)']#86
#df_si3[df_si3['사업장명']=='케이팥(K팥)'] #85
#df_si3[df_si3['사업장명']=='월간커피'] #96
df_si3.drop([1269],inplace=True)
df_si3.drop([743],inplace=True)
df_si3.drop([86],inplace=True)
df_si3.drop([85],inplace=True)
df_si3.drop([96],inplace=True)
df_si3.shape
# Out:
# (1609, 10)

# %%
df_si3.tail() #고미란
# Out:
#       index  Unnamed: 0  상세영업상태코드  소재지면적 지번주소                    사업장명 업태구분명  \
# 1609   1610      120786         1  24.00  문래동           토우토우(TOU TOU)   커피숍
# 1610   1611      120788         1  49.50  당산동         틈 커피(Tm coffee)   커피숍
# 1611   1612      120790         1  16.60  문래동       카페 엠아이티(Cafe MIT)   커피숍
# 1612   1613      120791         1  18.00  문래동                  브라운스케일   커피숍
# 1613   1614      120835         1  91.63  대림동  카페244 (카페다울 한국상하수도협회점)   커피숍
#
#         좌표정보(X)     좌표정보(Y)   자치구
# 1609  37.512976  126.894816  영등포구
# 1610  37.522951  126.899534  영등포구
# 1611  37.518441  126.889342  영등포구
# 1612  37.514834  126.886047  영등포구
# 1613  37.502487  126.896891  영등포구

# %%
df_si4 = df_si3.reset_index()
df_si4.tail() #인덱스부여 확인
# Out:
#       level_0  index  Unnamed: 0  상세영업상태코드  소재지면적 지번주소  \
# 1604     1609   1610      120786         1  24.00  문래동
# 1605     1610   1611      120788         1  49.50  당산동
# 1606     1611   1612      120790         1  16.60  문래동
# 1607     1612   1613      120791         1  18.00  문래동
# 1608     1613   1614      120835         1  91.63  대림동
#
#                         사업장명 업태구분명    좌표정보(X)     좌표정보(Y)   자치구
# 1604           토우토우(TOU TOU)   커피숍  37.512976  126.894816  영등포구
# 1605         틈 커피(Tm coffee)   커피숍  37.522951  126.899534  영등포구
# 1606       카페 엠아이티(Cafe MIT)   커피숍  37.518441  126.889342  영등포구
# 1607                  브라운스케일   커피숍  37.514834  126.886047  영등포구
# 1608  카페244 (카페다울 한국상하수도협회점)   커피숍  37.502487  126.896891  영등포구

# %%
df_si4.tail()
# Out:
#       level_0  index  Unnamed: 0  상세영업상태코드  소재지면적 지번주소  \
# 1604     1609   1610      120786         1  24.00  문래동
# 1605     1610   1611      120788         1  49.50  당산동
# 1606     1611   1612      120790         1  16.60  문래동
# 1607     1612   1613      120791         1  18.00  문래동
# 1608     1613   1614      120835         1  91.63  대림동
#
#                         사업장명 업태구분명    좌표정보(X)     좌표정보(Y)   자치구
# 1604           토우토우(TOU TOU)   커피숍  37.512976  126.894816  영등포구
# 1605         틈 커피(Tm coffee)   커피숍  37.522951  126.899534  영등포구
# 1606       카페 엠아이티(Cafe MIT)   커피숍  37.518441  126.889342  영등포구
# 1607                  브라운스케일   커피숍  37.514834  126.886047  영등포구
# 1608  카페244 (카페다울 한국상하수도협회점)   커피숍  37.502487  126.896891  영등포구

# %%
#여기정답
from folium.plugins import MarkerCluster

# Draw a basemap
m = folium.Map(location=[37.526359, 126.933522], zoom_start=14) 

# Add  points to the map
mc = MarkerCluster()
for i in range(1609):#오류잡아야함
    mc.add_child(Marker(location = [df_si4.loc[i, "좌표정보(X)"], df_si4.loc[i, "좌표정보(Y)"]],
               popup=df_si4.loc[i,'사업장명']))
    
m.add_child(mc)

m.save('영등포구까페모음.html')
m

#오류이유: 특수문자->454,1269 드랍
#서초구 카페 드랍완료
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save('영등포구까페모음.html')

# %%
# import folium
# m = folium.Map(location=[37.58, 127.0], tiles='openstreetmap', zoom_start=11)
# [출처] [Folium] Point 시각화 (Marker, Marker Cluster, Circle)|작성자 rackhunson
# from folium import Marker
# for _, row in library.iterrows():
#     Marker(location = [df_si2.loc[0, "좌표정보(X)"], df_si2.loc[0, "좌표정보(Y)"]],
#            popup=df_si2.loc[0,'사업장명'],
#            icon=folium.Icon(color='blue',icon='star')
#           ).add_to(m)

# %%
# 파일통일 필요
